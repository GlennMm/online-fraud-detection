# %%
import pandas as pd
import tensorflow.keras as keras
import numpy as np
import sklearn.metrics as metrics
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout, Flatten
from imblearn.under_sampling import RandomUnderSampler

sns.set()
# Out:
# 2021-07-16 23:11:36.871899: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-07-16 23:11:36.871983: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 100

# %%
data = pd.read_csv('../api/api/data/clean/merged_train_n_identity.csv')
data.drop(['Unnamed: 0', 'TransactionDT', 'TransactionID'], inplace=True, axis=1)
X = data.drop(['isFraud'], axis=1)
Y = data['isFraud']

rus = RandomUnderSampler()
x, y = rus.fit_resample(X,Y)

# %%
x
# Out:
# 1872  14.391835    0.0000    0.0000    0.0000   0.0
#
#        V215  V216      V217      V218      V219     V220      V221      V222  \
# 0       0.0   0.0  0.000000  0.000000  0.000000  0.00000  1.000000  1.000000
# 1       0.0   0.0  0.000000  0.000000  0.000000  0.00000  1.000000  1.000000
# 2       0.0   0.0  0.000000  0.000000  0.000000  0.00000  1.000000  1.000000
# 3       0.0   0.0  0.000000  0.000000  0.000000  0.00000  1.000000  1.000000
# 4       0.0   0.0  1.000000  1.000000  1.000000  0.00000  0.000000  0.000000
# ...     ...   ...       ...       ...       ...      ...       ...       ...
# 22631   0.0   0.0  1.055309  1.721008  1.366165  0.00000  0.000000  0.000000
# 22632   0.0   0.0  1.055309  1.721008  1.366165  0.00000  0.000000  0.000000
# 22633   0.0   0.0  0.000000  0.000000  0.000000  0.00000  1.000000  1.000000
# 22634   0.0   0.0  0.000000  0.000000  0.000000  0.16983  1.276338  1.360481
# ...

# %%
x_std = StandardScaler().fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x, y)


def confusion_metrics(y_true, y_pred):
    cn = metrics.confusion_matrix(y_true=y_true, y_pred=y_pred)
    print(cn)
    sns.heatmap(
        cn,
        annot=True,
        xticklabels=['Legit', 'Fraud'],
        yticklabels=['Legit', 'Fraud'],
        cmap='tab10')

# %%
len(x_std[0])
# Out:
# 431

# %%
def build_model(hp):
    model = keras.models.Sequential()
    model.add(Dense(hp.Int('input_units', min_value=32, max_value=256, step=32), activation='relu', input_shape=x_train.shape[1:]))

    for i in range(hp.Int('num_layers', 1, 20)):
        model.add(Dense(hp.Int(f'units_{i}', min_value=32, max_value=256, step=32), activation='relu'))
    # model.add(Dropout(.3))

    # model.add(Dense(256, activation='relu'))
    # model.add(Dropout(.3))

    model.add(Dense(1, activation='sigmoid'))

    loss = keras.losses.BinaryCrossentropy()
    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    return model

# %%
#optimeizations

from kerastuner.tuners import RandomSearch

import time

LOG_DIR = f'logs/Log-{int(time.time())}'

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=2,
    executions_per_trial=2,
    directory=LOG_DIR
)

tuner.search(x=x_train, y=y_train, epochs=5, batch_size=64, validation_split=.2)
# Out:
# Trial 2 Complete [00h 00m 30s]
# val_accuracy: 0.6497349739074707
#
# Best val_accuracy So Far: 0.6497349739074707
# Total elapsed time: 00h 00m 50s
# INFO:tensorflow:Oracle triggered exit

# %%
mod = tuner.get_best_models()[0]
y_pred = mod.predict(x_test)

# %%
yp = np.argmax(y_pred, axis=-1).astype('int')
confusion_metrics(y_test, yp)
# Out:
# [[2867    0]
#  [2792    0]]

# %%
mod.save('models/fd_neural_network_101')

# %%
red = [p for p in [((o[0]/1)*100).round() for o in y_pred] if p > 70]
orange = [p for p in [((o[0]/1)*100).round() for o in y_pred] if 45 < p < 70]
green = [p for p in [((o[0]/1)*100).round() for o in y_pred] if p < 45]

# %%
print(len(red))
print(len(green))
print(len(orange))

# %%
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, AdaBoostClassifier, BaggingClassifier
import tensorflow as tf

# %%
def get_model():
    model = tf.keras.models.load_model('./models/fd_neural_network_101/')
    return model

dnn_clf = tf.keras.wrappers.scikit_learn.KerasClassifier(get_model, epochs=10, batch_size=10, verbose=0) 
dnn_clf.
bagging_clf = BaggingClassifier()
